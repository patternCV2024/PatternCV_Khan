# %% [markdown]
# <a href="https://github.com/amx122">Хань Євгеній</a>, 2024

# %% [markdown]
# ## Домашнє завдання

# %% [markdown]
# Розв'яжіть наступний комплекс задач. Складіть систему лінійних рівнянь і розв'яжіть її за допомогою модуля numpy

# %% [markdown]
# ### Задача 1

# %% [markdown]
# <p>З рівнянь <strong>(1)</strong> та <strong>(2)</strong>, можемо виразити <em>x</em> з обох:</p>
#
# <p><em>x</em> = 2250 - <em>y</em> (з рівняння <strong>(1)</strong>)</p>
# <p><em>x</em> = 1400 - <em>z</em> (з рівняння <strong>(2)</strong>)</p>
#
# <p>Прирівнюємо ці вирази:</p>
#
# <p>2250 - <em>y</em> = 1400 - <em>z</em></p>
#
# <p>Розпишемо:</p>
#
# <p>2250 - 1400 = <em>z</em> - <em>y</em></p>
#
# <p>850 = <em>z</em> - <em>y</em></p>
#
# <p>Це наше третє рівняння.</p>
#
# <p>Тепер можемо виразити <em>x</em> через <em>y</em> та <em>z</em>:</p>
#
# <p><em>x</em> = 2250 - <em>y</em></p>
#
# <p>Підставляємо це значення <em>x</em> в рівняння <strong>(3)</strong> та <strong>(4)</strong>:</p>
#
# <p>0.05(2250 - <em>y</em>) + 0.07<em>y</em> = 2500</p>
# <p>0.05(2250 - <em>y</em>) + 0.06<em>z</em> = 1200</p>
#
# <p>Розв'язавши цю систему рівнянь, отримаємо значення <em>y</em> та <em>z</em>. Після цього, можна обчислити значення <em>x</em> за допомогою одного з попередніх виразів.</p>
#
# <p>Отже, потрібно розв'язати систему з трьох рівнянь:</p>
#
# <p><em>x</em> + <em>y</em> = 2250</p>
# <p><em>x</em> + <em>z</em> = 1400</p>
# <p>850 = <em>z</em> - <em>y</em></p>
#
# <p>Та двох рівнянь:</p>
#
# <p>0.05<em>x</em> + 0.07<em>y</em> = 2500</p>
# <p>0.05<em>x</em> + 0.06<em>z</em> = 1200</p>
# ```+ 0.07y = 2500
# 0.05x + 0.06z = 1200

# %% [markdown]
# ### Задача 2

# %% [markdown]
# <p>Ми маємо систему рівнянь:</p>
#
# <p><em>x</em> + <em>y</em> + <em>z</em> = 1328 (всього моделей)</p>
# <p><em>x</em> = <em>y</em> - 120 (моделей iPhone 6 на 120 менше, ніж моделей iPhone 11)</p>
# <p><em>x</em> = <em>z</em> + 100 (моделей iPhone 6 на 100 більше, ніж моделей iPhone 12)</p>
#
# <p>Ми можемо об'єднати рівняння (2) та (3), щоб виразити <em>y</em> через <em>x</em> та <em>z</em>:</p>
#
# <p><em>y</em> - 120 = <em>z</em> + 100</p>
#
# <p>Або:</p>
#
# <p><em>y</em> = <em>z</em> + 220</p>
#
# <p>Тепер ми можемо підставити цей вираз для <em>y</em> у рівняння (1):</p>
#
# <p><em>x</em> + (<em>z</em> + 220) + <em>z</em> = 1328</p>
#
# <p>Розкриваємо дужки:</p>
#
# <p><em>x</em> + <em>z</em> + 220 + <em>z</em> = 1328</p>
#
# <p><em>x</em> + 2<em>z</em> + 220 = 1328</p>
#
# <p>Тепер ми можемо виразити <em>x</em> через <em>z</em>:</p>
#
# <p><em>x</em> = 1108 - 2<em>z</em></p>
#
# <p>Тепер ми можемо підставити цей вираз для <em>x</em> у рівняння (1), щоб виразити <em>z</em>:</p>
#
# <p>1108 - 2<em>z</em> + <em>z</em> + 220 + <em>z</em> = 1328</p>
#
# <p>1108 + <em>z</em> + 220 = 1328</p>
#
# <p>3<em>z</em> = 1328 - 1108 - 220</p>
#
# <p>3<em>z</em> = 0</p>
#
# <p>Отримали <em>z</em> = 0, що є неможливим, оскільки кількість моделей не може бути від'ємною.</p>
#
# <p>Це означає, що деяка частина системи рівнянь, ймовірно, була невірно побудована. Давайте переглянемо виходячи з початку і переформулюємо умови задачі.</p>
#
# <p>Назвемо кількість моделей iPhone 6, iPhone 11 і iPhone 12 як <em>x</em>, <em>y</em> і <em>z</em> відповідно.</p>
#
# <p>Ми маємо такі умови:</p>
#
# <p><em>x</em> + <em>y</em> + <em>z</em> = 1328 (всього моделей)</p>
# <p><em>x</em> = <em>y</em> - 120 (моделей iPhone 6 на 120 менше, ніж моделей iPhone 11)</p>
# <p><em>x</em> = <em>z</em> + 100 (моделей iPhone 6 на 100 більше, ніж моделей iPhone 12)</p>
#
# <p>Тепер ми можемо виразити <em>y</em> через <em>x</em> та <em>z</em>, використовуючи рівняння (2) та (3):</p>
#
# <p><em>y</em> = <em>x</em> + 120</p>
# <p><em>y</em> = <em>x</em> - 100</p>
#
# <p>Отже, ми маємо:</p>
#
# <p><em>x</em> + (<em>x</em> + 120) + (<em>x</em> - 100) = 1328</p>
#
# <p>Розв'язавши це рівняння, м
#
# и знайдемо значення <em>x</em>потім можемо знайти значення <em>y</em> та <em>z</em>.</p>
# ```

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Для знаходження канонічного рівняння еліпсоїда, який проходить через три точки \( A(\sqrt3; 0; \sqrt3), B(\sqrt6; \frac{1}{2}; 0), C(1; \frac{1}{\sqrt3}; 1) \), нам потрібно використати загальне рівняння еліпсоїда:
#
# $$
# \frac{x^2}{a^2} + \frac{y^2}{b^2} + \frac{z^2}{c^2} = 1
# $$
#
# де \( a^2, b^2, c^2 \) - параметри еліпсоїда.
#
# Ми можемо скласти систему рівнянь, підставивши координати кожної точки \( (x, y, z) \) у загальне рівняння еліпсоїда:
#
# 1. Для точки \( A(\sqrt3; 0; \sqrt3) \):
#
# $$
# \frac{(\sqrt3)^2}{a^2} + \frac{0^2}{b^2} + \frac{(\sqrt3)^2}{c^2} = 1
# $$
#
# 2. Для точки \( B(\sqrt6; \frac{1}{2}; 0) \):
#
# $$
# \frac{(\sqrt6)^2}{a^2} + \frac{\left(\frac{1}{2}\right)^2}{b^2} + \frac{0^2}{c^2} = 1
# $$
#
# 3. Для точки \( C(1; \frac{1}{\sqrt3}; 1) \):
#
# $$
# \frac{1^2}{a^2} + \frac{\left(\frac{1}{\sqrt3}\right)^2}{b^2} + \frac{1^2}{c^2} = 1
# $$
#
# Розв'язавши цю систему рівнянь, ми отримаємо значення параметрів \( a^2, b^2, c^2 \). Після цього ми зможемо підставити їх у загальне рівняння еліпсоїда.їда.

# %% [markdown]
# ### Задача 4

# %% [markdown]
# <p>Щоб скласти рівняння параболи, що проходить через три задані точки <span>\((1, 12)\)</span>, <span>\((3, 54)\)</span>, та <span>\((-1, 2)\)</span>, спочатку треба визначити коефіцієнти <em>a</em>, <em>b</em>, <em>c</em> у загальному рівнянні параболи <span>$$y = a \cdot x^2 + b \cdot x + c$$</span>.</p>
#
# <p>Ми можемо скласти систему трьох рівнянь, підставивши координати кожної з точок у загальне рівняння параболи:</p>
#
# <ol>
#   <li>Для точки <span>\((1, 12)\)</span>:</li>
#   <p>$$12 = a \cdot 1^2 + b \cdot 1 + c$$</p>
#   <li>Для точки <span>\((3, 54)\)</span>:</li>
#   <p>$$54 = a \cdot 3^2 + b \cdot 3 + c$$</p>
#   <li>Для точки <span>\((-1, 2)\)</span>:</li>
#   <p>$$2 = a \cdot (-1)^2 + b \cdot (-1) + c$$</p>
# </ol>
#
# <p>Отримаємо таку систему рівнянь. Розв'язавши її, отримаємо значення коефіцієнтів <em>a</em>, <em>b</em>, <em>c</em>, і після цього можна буде записати рівняння параболи.</p>
#
# <p>Якщо ми це зробимо, отримаємо таку систему рівнянь:</p>
#
# <ol>
#   <li>$$12 = a + b + c$$</li>
#   <li>$$54 = 9a + 3b + c$$</li>
#   <li>$$2 = a - b + c$$</li>
# </ol>
#
# <p>Розв'язавши цю систему, отримаємо значення коефіцієнтів <em>a</em>, <em>b</em>, <em>c</em>. Після цього ми зможемо записативняння параболи.</p>
# ```исати рівняння параболи.о рівняння параболи.ня параболи.t x + c\).тових даних.

# %% [markdown]
# ### Задача 5

# %%
import numpy as np

def get_polynom(coords):
    n = len(coords)  # Кількість точок
    x_values = [coord[0] for coord in coords]  # Список значень x
    y_values = [coord[1] for coord in coords]  # Список значень y

    # Створення матриці коефіцієнтів системи рівнянь
    a = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            a[i, j] = x_values[i] ** j

    # Створення вектора вільних членів
    b = np.array(y_values)

    # Знаходження коефіцієнтів многочлена за допомогою розв'язання системи лінійних рівнянь
    coefficients = np.linalg.solve(a, b)

    return coefficients
